# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
os.environ['COLAB_GPU'] = "1"

# !pip install colab_ssh --upgrade
ngrokToken = '1zueWzaDmKdiF67TunPrHC9rKmG_5oC3MJ9uRjr8GCiVwJxzM'
password = '45697mat'

from colab_ssh import launch_ssh, init_git

personal_token = "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"
repository_url = "https://github.com/shengyenlin/DLA"
branch = "main"
email = "shengyenlin0501@gmail.com"
username = "shengyenlin0501"
init_git(
    repository_url = repository_url,
    branch = branch,
    personal_token = personal_token,
    email = email,
    username = username
)

launch_ssh(ngrokToken,password)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ...
# Successfully cloned the repository in ./DLA
# ...
# we highly recommend that update your code by following this documentation https://github.com/WassimBenzarti/colab-ssh#getting-started
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /usr/local/lib/python3.7/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ...

# %%
123

# %%
while True:
  pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-648a2bab0435> in <module>()
#       1 while True:
# ----> 2   pass
#
# KeyboardInterrupt:
