# %% [markdown]
# # Package

# %%
#Pytorch
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torchvision import models
from torch.utils.data import DataLoader, Dataset

#For data preprocessing
import numpy as np
import pandas as pd
import itertools
from sklearn.preprocessing import StandardScaler
import os
import random
import csv
import gc

#For plotting
import matplotlib.pyplot as plt

#For reproducibility
myseed = 42069  # set a random seed for reproducibility
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# # Data Preprocessing

# %%
class DataPreprocessor:
    def __init__(self, preprocess_params):
        self.num_lag = preprocess_params["num_lag"]
        self.train_valid_ratio = preprocess_params["train_valid_ratio"]
        self.p_value_threshold = preprocess_params["p_value_threshold"]
        self.scaler = None

    def preproces_train_data(self, data_path):
        """
        get_lag_variable -> correlation coefficient -> split_train_valid -> normalize
        """
        data = pd.read_csv(data_path)
        X = data.loc[:, data.columns != "PM2.5"]
        y = data.loc[:, data.columns == "PM2.5"]
        X = self.get_lag_variable(X, self.num_lag, isTesting = False)
        X = X.dropna()
        X = self.do_correlation_coefficient_test(X, y, self.p_value_threshold)
        X_train, X_valid, y_train, y_valid = self.split_train_valid(X, y, self.train_valid_ratio)
        X_train = self.normalize(X_train, isTraining=True)
        X_valid = self.normalize(X_valid, isTraining=False)
        return X_train, X_valid, np.array(y_train), np.array(y_valid)

    def preprocess_test_data(self, data_path):
        """
        get_lag_variable -> correlation coefficient -> normalize
        """
        X_test = pd.read_csv(data_path)
        X_test = self.get_lag_variable(X_test, self.num_lag, isTesting = True)
        X_test = X_test[self.kept_columns]
        X_test = self.normalize(X_test, isTraining=False)
        return X_test

    def normalize(self, data, isTraining = False):
        if isTraining:
            self.scaler = StandardScaler().fit(data)
        data_scaled = self.scaler.transform(data)
        return data_scaled

    def do_correlation_coefficient_test(self, X, y, p_value_threshold):
        corr_features = abs(X.corrwith(y['PM2.5'])).sort_values(ascending=False)
        print(corr_features)
        self.kept_columns = (corr_features[corr_features > p_value_threshold]).index
        X = X[self.kept_columns]
        return X

    def split_train_valid(self, X, y, train_valid_ratio = 0.75):
        data_len = len(X)
        train_len = round(train_valid_ratio * data_len)
        train_index = random.sample(range(data_len), train_len)
        valid_index = [i for i in range(data_len) if i not in train_index]
        X_train = X.iloc[train_index, :]
        y_train = y.iloc[train_index, :]
        X_valid = X.iloc[valid_index, :]
        y_valid = y.iloc[valid_index, :]
        return X_train, X_valid, y_train, y_valid

    def get_lag_variable(self, data: pd.DataFrame, num_lag: int, isTesting = False):
        #start from 0
        data_ = data.copy()
        for idx in range(num_lag):
            #start from 1
            time = idx + 1
            lag_data = data.shift(time)
            lag_data.columns = [col + "_" + str(-time) for col in data.columns]
            data_ = pd.concat([data_, lag_data], axis = 1)
        #fill testing set nan with "mean" 
        if isTesting:
            data_.fillna(data_.mean(), inplace = True)
        return data_

# %%
data_path = "./data/"
train_path = os.path.join(data_path, "training_data.csv")
test_path = os.path.join(data_path, "testing_data.csv")
preprocess_params = {
    "num_lag": 7,
    "train_valid_ratio": 0.75,
    "p_value_threshold": 0.5
}

DP = DataPreprocessor(preprocess_params)
X_train, X_valid, y_train, y_valid = DP.preproces_train_data(train_path)
X_test = DP.preprocess_test_data(test_path)
# Out:
# PM10       0.854647
# PM10_-1    0.838010
# PM10_-2    0.797987
# PM10_-3    0.751594
# PM10_-4    0.707345
#              ...
# NO_-6      0.025897
# RH_-3      0.024222
# RH_-5      0.022119
# RH_-4      0.019992
# NO_-7      0.004001
# Length: 80, dtype: float64

# %%
print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
# Out:
# (6583, 20)
# (2194, 20)
# (8760, 20)

# %%
class EPADataSet(Dataset):
    """Dataset for loading and preprocessing the EPA Weather data
    """
    def __init__(self, X, y = None, mode = "train"):
        self.mode = mode
        if mode in ["train", "valid"]:
            self.data = torch.from_numpy(X).float()
            self.target = torch.from_numpy(y.reshape(-1, 1)).float()
            self.dim = X.shape[1]
            print(f"Check nan...")
            if not np.any(np.isnan(X)) and not np.any(np.isnan(y)):
                print("No nan in dataset.")
        else:
            self.data = torch.from_numpy(X).float()
            self.dim = X.shape[1]
            print(f"Check nan...")
            if not np.any(np.isnan(X)):
                print("No nan in dataset.")

        print(f"Finish reading {self.mode} dataset ({len(self.data)} samples, {self.dim} features)")
        if mode in ["train", "valid"]:
            print(f"Check target size... The target size is {len(self.target)}")
        
    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        if self.mode in ["train", "valid"]:
            return self.data[index], self.target[index]
        else:
            return self.data[index]

# %%
def prep_dataloader(mode, batch_size, X, y = None):
    """Generates a dataset, then is put into a dataloader. 
    """
    dataset = EPADataSet(X, y, mode)
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle = (mode == "train"), drop_last=False, pin_memory = True)
    return dataloader

# %% [markdown]
# # Modeling

# %%
def get_device():
    ''' Get device (if GPU is available, use GPU) '''
    return 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def plot_curve(train_loss, valid_loss):
    num_epoch = len(train_loss)
    x = [i+1 for i in range(num_epoch)]
    plt.plot(x, train_loss)
    plt.plot(x, valid_loss)
    plt.legend(["Training loss", "Validation loss"])
    plt.show()

# %%
class NeuralNet(nn.Module):
    ''' A simple fully-connected deep neural network '''
    def __init__(self, input_dim):
        super(NeuralNet, self).__init__()
        self.net = nn.Sequential(
            #input layer
            nn.Linear(input_dim, 32), 
            nn.ReLU(),
            
            #hidden layer
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 4),
            nn.ReLU(),

            #output layer
            nn.Linear(4, 1)
        )

        self.net.apply(self.init_weights)
        self.criterion = nn.MSELoss(reduction='mean')

    def init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            m.bias.data.fill_(0.01)

    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        return self.net(x)

    def cal_loss(self, pred, target):
        ''' Calculate loss '''
        return self.criterion(pred, target)

# %%
def train(model, train_set, valid_set, params_set, device, verbose = False):
    #params settings
    num_epoch = params_set["num_epoch"]
    optimizer = getattr(torch.optim, params_set['optimizer'])(
    model.parameters(), **params_set['optim_hparams'])
    patience = params_set["patience"]

    #recording
    best_train_MSE = 0
    best_valid_MSE = 99999
    best_epoch = 0
    loss_record = {"train": [], "valid": []}

    #start training
    for idx_epoch in range(num_epoch):
        model.train()
        train_SSE = 0
        for idx, train_data in enumerate(train_set):
            X, y = train_data
            X, y = X.to(device), y.to(device)
            optimizer.zero_grad()
            train_pred = model(X)
            train_loss = model.cal_loss(train_pred.flatten(), y.flatten())
            train_loss.backward()
            optimizer.step()
            train_SSE += (train_loss.detach().cpu().item()) * len(X)
        train_MSE = train_SSE / len(train_set.dataset)
        loss_record["train"].append(train_MSE)
        #validation
        valid_MSE = valid(model, valid_set, device)
        loss_record["valid"].append(valid_MSE)

        if verbose:
            print(f"Epoch {idx_epoch}, Train loss: {round(train_MSE, 4)}, Valid loss: {round(valid_MSE, 4)}")

        #save best result
        if valid_MSE < best_valid_MSE:
            best_valid_MSE = valid_MSE
            best_train_MSE = train_MSE
            best_epoch = idx_epoch
        
        #early stopping
        if valid_MSE > best_valid_MSE and idx_epoch >= best_epoch + patience:
            print("="*50)
            print("Early Stopping!")
            print(f"Best epoch is {best_epoch}, training loss = {round(best_train_MSE, 4)}, minimum valid loss = {round(best_valid_MSE, 4)}")
            return loss_record, model

    #Training until the final epoch
    print("=" * 50)
    print("Model result:")
    print(f"Best epoch is {best_epoch}, training loss = {round(best_train_MSE, 4)}, minimum valid loss = {round(best_valid_MSE, 4)}")
    return loss_record, model

def valid(model, valid_set, device):
    valid_SSE = 0
    with torch.no_grad():
        model.eval()     
        for idx, valid_data in enumerate(valid_set):
            X, y = valid_data
            X, y = X.to(device), y.to(device)
            valid_pred = model(X)
            valid_loss = model.cal_loss(valid_pred, y)
            valid_SSE += (valid_loss.detach().cpu().item()) * len(X)
    valid_MSE = valid_SSE / len(valid_set.dataset)
    return valid_MSE

def test(model, test_set, device):
    preds = []
    with torch.no_grad():
        model.eval()
        for X in test_set:
            X = X.to(device)
            test_pred = model(X)
            preds.append(test_pred.flatten().detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
    return preds

# %%
params_set = {
    "num_batch": [512], 
    "num_epoch": [20, 50],
    #optimizer
    "optimizer": ["Adam"],
    "optim_hparams": [{
        "lr": [0.5, 0.1, 0.05, 0.01, 0.005],
        "weight_decay": [0.001, 0.005, 0.01, 0.05, 0.1, 1, 5, 10]
    }],
    #for early stopping
    "patience": [5, 15]
}

param_grid = []
count = 0
for values in itertools.product(*params_set.values()):
    param = dict(zip(params_set.keys(), values))
    for optim_values in itertools.product(*param["optim_hparams"].values()):
        param_copy = param.copy()
        param_copy["optim_hparams"] = dict(zip(param["optim_hparams"].keys(), optim_values))
        param_grid.append(param_copy)

# %%
train_set = prep_dataloader("train", params_set["num_batch"][0], X_train, y_train)
valid_set = prep_dataloader("valid", params_set["num_batch"][0], X_valid, y_valid)
test_set = prep_dataloader("test", params_set["num_batch"][0], X_test)
# Out:
# Check nan...
# No nan in dataset.
# Finish reading train dataset (6583 samples, 20 features)
# Check target size... The target size is 6583
# Check nan...
# No nan in dataset.
# Finish reading valid dataset (2194 samples, 20 features)
# Check target size... The target size is 2194
# Check nan...
# No nan in dataset.
# Finish reading test dataset (8760 samples, 20 features)

# %%
X, y = next(iter(train_set))
print(X[:10], y[:10])
# Out:
# tensor([[ 3.0248e-01,  6.0055e-01,  9.6553e-01,  8.6897e-01,  7.4262e-01,
#           6.1528e-01,  9.9239e-01,  5.1046e-02, -1.7885e-01,  1.2329e+00,
#          -1.7476e-01,  1.1652e+00, -4.7045e-01,  5.6321e-01,  5.5880e-01,
#           1.2982e+00,  1.1528e+00,  5.5752e-01,  1.4659e+00,  4.5109e-02,
#           5.5831e-01,  1.1507e+00, -3.2081e-02],
#         [-9.7225e-02,  4.0105e-01,  5.0000e-01,  8.6897e-01,  8.7661e-01,
#           1.7830e-01,  1.2614e-02, -6.1547e-03,  2.2140e-01, -1.8729e-01,
#          -2.6677e-03,  3.1646e-01,  6.2035e-01, -2.5293e-02, -2.9213e-02,
#           4.5548e-01, -2.6929e-02, -2.9183e-02,  2.5145e-01,  5.6726e-01,
#          -2.9695e-02, -2.6733e-02, -6.1764e-01],
#         [-9.6325e-01, -1.0952e+00, -1.0961e+00, -1.2306e+00, -1.2672e+00,
#          -1.0654e+00, -1.1023e+00, -1.7776e-01, -6.9346e-01, -8.9739e-01,
#          -2.3212e-01, -9.9806e-01, -5.2786e-01, -6.1379e-01, -6.1723e-01,
#          -6.5697e-01, -6.1679e-01, -6.1588e-01, -6.9312e-01, -4.1903e-01,
#          -6.1770e-01, -6.1544e-01, -3.2081e-02],
#         [-8.6332e-01, -1.1949e+00, -1.4286e+00, -1.5972e+00, -1.2672e+00,
#          -1.2671e+00, -1.3050e+00,  1.6545e-01,  3.3576e-01, -1.4384e+00,
#           1.6943e-01, -1.0319e+00,  5.6294e-01,  5.6321e-01,  5.5880e-01,
#          -7.5810e-01,  5.6293e-01, -2.9183e-02, -7.6059e-01,  2.1916e-01,
#           5.5831e-01,  5.6197e-01,  5.5348e-01],
#         [-1.2111e+00, -1.2209e+00, -1.1662e+00, -1.2566e+00, -1.2820e+00,
#          -1.2970e+00, -1.2787e+00,  1.2523e+00, -7.5064e-01, -1.2207e+00,
#           1.7756e+00, -1.2157e+00, -1.0446e+00, -6.1379e-01, -6.1723e-01,
#          -1.2489e+00, -6.1679e-01, -6.1588e-01, -1.2244e+00, -1.1732e+00,
#          -6.1770e-01, -6.1544e-01, -6.1764e-01],
#         [ 6.3556e-01,  2.0155e-01, -9.8532e-02, -9.7484e-02, -1.9530e-01,
#          -4.2675e-01, -5.9552e-01,  6.8025e-01,  1.0791e+00, -7.2832e-01,
#           4.5625e-01, -6.2625e-01,  1.3667e+00,  5.6321e-01,  5.5880e-01,
#          -6.2326e-01,  5.6293e-01,  5.5752e-01, -6.2566e-01,  5.6726e-01,
#          -2.9695e-02, -2.6733e-02, -3.2081e-02],
#         [-3.9700e-01, -5.9644e-01, -4.6430e-01, -4.6407e-01, -2.2880e-01,
#          -9.0610e-02, -1.5631e-01, -4.0656e-01, -4.0757e-01, -3.2254e-01,
#          -6.9104e-01, -4.5724e-01, -4.1304e-01, -6.1379e-01, -6.1723e-01,
#          -2.8615e-01, -2.6929e-02,  5.5752e-01, -8.5901e-02, -7.0925e-02,
#           5.5831e-01, -6.1544e-01, -3.2081e-02],
#         [-8.6332e-01, -1.0952e+00, -1.1626e+00, -9.9729e-01, -8.6525e-01,
#          -6.6205e-01, -8.9959e-01, -6.3355e-02, -6.3628e-01, -8.6358e-01,
#          -1.1740e-01, -7.6145e-01, -9.2974e-01, -6.1379e-01, -6.1723e-01,
#          -6.2326e-01,  5.6293e-01,  1.1442e+00, -7.6059e-01, -4.7704e-01,
#           5.5831e-01, -2.6733e-02, -3.2081e-02],
#         [ 7.3549e-01,  1.3653e+00,  1.5973e+00,  1.4688e+00,  1.1111e+00,
#           8.1697e-01,  4.5182e-01,  2.7985e-01,  4.5011e-01,  3.8756e-01,
#          -6.3367e-01,  1.5117e-01,  6.7776e-01, -2.5293e-02,  5.5880e-01,
#           3.5435e-01, -2.6929e-02,  5.5752e-01,  4.5385e-01,  1.1474e+00,
#           2.3223e+00, -6.1544e-01,  2.8957e+00],
#         [-1.9715e-01, -2.3069e-01, -2.6479e-01, -4.9740e-01, -7.6476e-01,
#          -7.6289e-01, -5.9552e-01, -5.2096e-01, -1.2167e-01, -1.8214e-02,
#          -6.0032e-02,  8.3570e-02, -6.8579e-02,  5.6321e-01,  5.5880e-01,
#          -8.3889e-02,  1.1528e+00,  5.5752e-01, -1.5337e-01, -7.0925e-02,
#          -2.9695e-02,  5.6197e-01, -3.2081e-02]]) tensor([[87.2000],
#         [13.1000],
#         [ 5.3000],
#         [11.8000],
#         [28.7000],
#         [10.5000],
#         [36.5000],
#         [ 7.9000],
#         [61.2000],
#         [31.3000]])

# %%
device = get_device() 
os.makedirs('models', exist_ok=True)

# %%
param_grid = []
count = 0
for values in itertools.product(*params_set.values()):
    param = dict(zip(params_set.keys(), values))
    for optim_values in itertools.product(*param["optim_hparams"].values()):
        param_copy = param.copy()
        param_copy["optim_hparams"] = dict(zip(param["optim_hparams"].keys(), optim_values))
        param_grid.append(param_copy)

# %%
best_valid_loss = 10 ** 7
best_train_loss = 0
best_loss_record = None
best_model = None
best_params = None
count = 0

for param in param_grid:
        print("Parameter settings:")
        print(param)
        model = NeuralNet(train_set.dataset.dim).to(device)  # Construct model and move to device
        loss_record, local_best_model = train(model, train_set, valid_set, param, device, verbose = True)
        if min(loss_record["valid"]) < best_valid_loss:
            best_valid_loss = min(loss_record["valid"])
            best_train_loss = min(loss_record["train"])
            best_loss_record = loss_record
            best_model = local_best_model
            best_params = param
        print("="*50)
        count += 1
# Out:
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.5, 'weight_decay': 0.001}, 'patience': 5}
# Epoch 0, Train loss: 20532.3617, Valid loss: 2322.8905
# Epoch 1, Train loss: 2125.4439, Valid loss: 2164.5578
# Epoch 2, Train loss: 1941.5457, Valid loss: 1952.0941
# Epoch 3, Train loss: 1732.6761, Valid loss: 1737.6282
# Epoch 4, Train loss: 1532.3262, Valid loss: 1541.9951
# Epoch 5, Train loss: 1354.556, Valid loss: 1372.28
# Epoch 6, Train loss: 1203.6201, Valid loss: 1229.9212
# Epoch 7, Train loss: 1079.5974, Valid loss: 1113.7111
# Epoch 8, Train loss: 980.0648, Valid loss: 1021.331
# Epoch 9, Train loss: 902.7752, Valid loss: 949.2124
# Epoch 10, Train loss: 842.8607, Valid loss: 895.1116
# Epoch 11, Train loss: 799.2645, Valid loss: 854.0806
# Epoch 12, Train loss: 767.1887, Valid loss: 823.7743
# Epoch 13, Train loss: 744.158, Valid loss: 802.0086
# Epoch 14, Train loss: 728.1281, Valid loss: 786.5723
# Epoch 15, Train loss: 717.0731, Valid loss: 775.8854
# Epoch 16, Train loss: 709.9516, Valid loss: 768.1996
# Epoch 17, Train loss: 705.1406, Valid loss: 762.9489
# Epoch 18, Train loss: 701.8942, Valid loss: 759.5836
# Epoch 19, Train loss: 700.0193, Valid loss: 757.2065
# ==================================================
# Model result:
# Best epoch is 19, training loss = 700.0193, minimum valid loss = 757.2065
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.5, 'weight_decay': 0.005}, 'patience': 5}
# Epoch 0, Train loss: 128912.2949, Valid loss: 2388.3432
# Epoch 1, Train loss: 2240.3763, Valid loss: 2347.273
# Epoch 2, Train loss: 2172.45, Valid loss: 2252.7788
# Epoch 3, Train loss: 2069.6869, Valid loss: 2137.7196
# Epoch 4, Train loss: 1953.9832, Valid loss: 2014.673
# Epoch 5, Train loss: 1833.4996, Valid loss: 1891.3021
# Epoch 6, Train loss: 1714.7692, Valid loss: 1770.5748
# Epoch 7, Train loss: 1600.2979, Valid loss: 1654.8238
# Epoch 8, Train loss: 1491.4342, Valid loss: 1546.4067
# Epoch 9, Train loss: 1390.7344, Valid loss: 1445.5356
# Epoch 10, Train loss: 1297.3241, Valid loss: 1353.9757
# Epoch 11, Train loss: 1213.3432, Valid loss: 1270.7795
# Epoch 12, Train loss: 1137.5915, Valid loss: 1196.4007
# Epoch 13, Train loss: 1070.803, Valid loss: 1130.0369
# Epoch 14, Train loss: 1011.7827, Valid loss: 1071.712
# Epoch 15, Train loss: 959.8676, Valid loss: 1021.425
# Epoch 16, Train loss: 915.4702, Valid loss: 977.8243
# Epoch 17, Train loss: 877.5605, Valid loss: 940.0553
# Epoch 18, Train loss: 844.6611, Valid loss: 908.3167
# Epoch 19, Train loss: 817.8296, Valid loss: 880.7203
# ==================================================
# Model result:
# Best epoch is 19, training loss = 817.8296, minimum valid loss = 880.7203
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.5, 'weight_decay': 0.01}, 'patience': 5}
# Epoch 0, Train loss: 2780.3687, Valid loss: 2056.9965
# Epoch 1, Train loss: 1764.6815, Valid loss: 1690.9812
# Epoch 2, Train loss: 1432.1833, Valid loss: 1385.681
# Epoch 3, Train loss: 1175.5349, Valid loss: 1158.1333
# Epoch 4, Train loss: 991.3483, Valid loss: 1000.9551
# Epoch 5, Train loss: 868.5158, Valid loss: 898.6717
# Epoch 6, Train loss: 1159.893, Valid loss: 825.5764
# Epoch 7, Train loss: 738.8689, Valid loss: 790.2968
# Epoch 8, Train loss: 717.1685, Valid loss: 771.9871
# Epoch 9, Train loss: 706.0988, Valid loss: 762.7429
# Epoch 10, Train loss: 701.0999, Valid loss: 757.8944
# Epoch 11, Train loss: 698.8966, Valid loss: 755.2543
# Epoch 12, Train loss: 697.9635, Valid loss: 753.7308
# Epoch 13, Train loss: 697.4944, Valid loss: 753.0083
# Epoch 14, Train loss: 697.275, Valid loss: 752.7774
# Epoch 15, Train loss: 697.2192, Valid loss: 752.5935
# Epoch 16, Train loss: 697.1912, Valid loss: 752.4523
# Epoch 17, Train loss: 697.2024, Valid loss: 752.4729
# Epoch 18, Train loss: 697.1809, Valid loss: 752.3815
# Epoch 19, Train loss: 697.1575, Valid loss: 752.3406
# ==================================================
# Model result:
# Best epoch is 19, training loss = 697.1575, minimum valid loss = 752.3406
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.5, 'weight_decay': 0.05}, 'patience': 5}
# Epoch 0, Train loss: 58289.7725, Valid loss: 2367.415
# Epoch 1, Train loss: 2203.0891, Valid loss: 2286.8612
# Epoch 2, Train loss: 2258.8704, Valid loss: 2145.7159
# Epoch 3, Train loss: 1939.0276, Valid loss: 1738.7171
# Epoch 4, Train loss: 28009.9653, Valid loss: 1654.315
# Epoch 5, Train loss: 1456.6729, Valid loss: 1455.3963
# Epoch 6, Train loss: 40909.6314, Valid loss: 2049.2004
# Epoch 7, Train loss: 1925.2924, Valid loss: 1920.1511
# Epoch 8, Train loss: 1596.074, Valid loss: 1557.0588
# Epoch 9, Train loss: 1393.1092, Valid loss: 1438.3994
# Epoch 10, Train loss: 1284.892, Valid loss: 1333.6264
# Epoch 11, Train loss: 1189.8656, Valid loss: 1241.5188
# Epoch 12, Train loss: 1107.6616, Valid loss: 1160.747
# Epoch 13, Train loss: 1035.8229, Valid loss: 1091.8881
# Epoch 14, Train loss: 974.9081, Valid loss: 1033.0967
# Epoch 15, Train loss: 923.1825, Valid loss: 983.582
# Epoch 16, Train loss: 880.7572, Valid loss: 941.1212
# Epoch 17, Train loss: 844.6655, Valid loss: 906.1327
# Epoch 18, Train loss: 815.1688, Valid loss: 877.2453
# Epoch 19, Train loss: 791.089, Valid loss: 853.6138
# ==================================================
# Model result:
# Best epoch is 19, training loss = 791.089, minimum valid loss = 853.6138
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.5, 'weight_decay': 0.1}, 'patience': 5}
# Epoch 0, Train loss: 23862.1326, Valid loss: 2322.8928
# Epoch 1, Train loss: 2486.232, Valid loss: 2189.2657
# Epoch 2, Train loss: 2043.8491, Valid loss: 2001.8758
# Epoch 3, Train loss: 1782.7755, Valid loss: 1789.5952
# Epoch 4, Train loss: 2194.7519, Valid loss: 1605.0157
# Epoch 5, Train loss: 1418.716, Valid loss: 1435.3321
# Epoch 6, Train loss: 1261.5458, Valid loss: 1286.4976
# Epoch 7, Train loss: 1163.8732, Valid loss: 1207.5715
# Epoch 8, Train loss: 1025.4209, Valid loss: 1062.9596
# Epoch 9, Train loss: 938.3463, Valid loss: 985.9275
# Epoch 10, Train loss: 874.5509, Valid loss: 926.1818
# Epoch 11, Train loss: 826.0895, Valid loss: 881.1555
# Epoch 12, Train loss: 790.1885, Valid loss: 847.7274
# Epoch 13, Train loss: 764.0445, Valid loss: 823.1486
# Epoch 14, Train loss: 745.2071, Valid loss: 805.2878
# Epoch 15, Train loss: 731.9112, Valid loss: 792.3023
# Epoch 16, Train loss: 722.4866, Valid loss: 782.9591
# Epoch 17, Train loss: 715.8311, Valid loss: 776.3219
# Epoch 18, Train loss: 711.2741, Valid loss: 771.4233
# Epoch 19, Train loss: 708.0915, Valid loss: 767.6998
# ==================================================
# Model result:
# Best epoch is 19, training loss = 708.0915, minimum valid loss = 767.6998
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.5, 'weight_decay': 1}, 'patience': 5}
# Epoch 0, Train loss: 30475.1863, Valid loss: 1767.1342
# Epoch 1, Train loss: 2487.7874, Valid loss: 2498.5653
# Epoch 2, Train loss: 2318.2487, Valid loss: 2101.7196
# Epoch 3, Train loss: 1884.9368, Valid loss: 1905.2505
# Epoch 4, Train loss: 1700.1621, Valid loss: 1721.152
# Epoch 5, Train loss: 1532.2725, Valid loss: 1561.8656
# Epoch 6, Train loss: 1389.726, Valid loss: 1427.8485
# Epoch 7, Train loss: 1271.3257, Valid loss: 1318.7092
# Epoch 8, Train loss: 1177.4326, Valid loss: 1230.1375
# Epoch 9, Train loss: 1100.1848, Valid loss: 1159.6742
# Epoch 10, Train loss: 1040.3825, Valid loss: 1106.1382
# Epoch 11, Train loss: 995.0989, Valid loss: 1063.0734
# Epoch 12, Train loss: 959.3453, Valid loss: 1030.8775
# Epoch 13, Train loss: 932.8309, Valid loss: 1006.8274
# Epoch 14, Train loss: 913.0757, Valid loss: 988.9287
# Epoch 15, Train loss: 898.5012, Valid loss: 975.9163
# Epoch 16, Train loss: 887.6772, Valid loss: 965.9056
# Epoch 17, Train loss: 879.5661, Valid loss: 958.5758
# Epoch 18, Train loss: 873.8128, Valid loss: 953.5021
# Epoch 19, Train loss: 869.7189, Valid loss: 949.8371
# ==================================================
# Model result:
# Best epoch is 19, training loss = 869.7189, minimum valid loss = 949.8371
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.5, 'weight_decay': 5}, 'patience': 5}
# Epoch 0, Train loss: 10976.2658, Valid loss: 2554.0129
# Epoch 1, Train loss: 1990.5018, Valid loss: 1781.0726
# Epoch 2, Train loss: 2307.2306, Valid loss: 2187.6736
# Epoch 3, Train loss: 1930.8602, Valid loss: 1788.0046
# Epoch 4, Train loss: 1599.5291, Valid loss: 1646.0452
# Epoch 5, Train loss: 1494.923, Valid loss: 1574.1248
# Epoch 6, Train loss: 1448.2946, Valid loss: 1548.5279
# Epoch 7, Train loss: 1436.3445, Valid loss: 1547.9875
# Epoch 8, Train loss: 1438.7514, Valid loss: 1552.9281
# Epoch 9, Train loss: 1444.7327, Valid loss: 1558.8364
# Epoch 10, Train loss: 1447.2672, Valid loss: 1560.2089
# Epoch 11, Train loss: 1449.186, Valid loss: 1560.7146
# Epoch 12, Train loss: 1450.0486, Valid loss: 1563.0553
# ==================================================
# Early Stopping!
# Best epoch is 7, training loss = 1436.3445, minimum valid loss = 1547.9875
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.5, 'weight_decay': 10}, 'patience': 5}
# Epoch 0, Train loss: 11962.5614, Valid loss: 2535.9507
# Epoch 1, Train loss: 2107.2083, Valid loss: 2050.2551
# Epoch 2, Train loss: 1862.7211, Valid loss: 1884.7579
# Epoch 3, Train loss: 1432.6412, Valid loss: 798.3352
# Epoch 4, Train loss: 585.6096, Valid loss: 611.5126
# Epoch 5, Train loss: 609.9038, Valid loss: 218.6358
# Epoch 6, Train loss: 292.0696, Valid loss: 239.6413
# Epoch 7, Train loss: 208.0406, Valid loss: 204.4224
# Epoch 8, Train loss: 221.6081, Valid loss: 207.2458
# Epoch 9, Train loss: 194.8033, Valid loss: 216.2091
# Epoch 10, Train loss: 219.0879, Valid loss: 224.0975
# Epoch 11, Train loss: 214.4635, Valid loss: 198.2825
# Epoch 12, Train loss: 186.3444, Valid loss: 186.0739
# Epoch 13, Train loss: 278.3288, Valid loss: 449.1293
# Epoch 14, Train loss: 321.4046, Valid loss: 253.2298
# Epoch 15, Train loss: 262.6691, Valid loss: 233.4801
# Epoch 16, Train loss: 217.5045, Valid loss: 197.2875
# Epoch 17, Train loss: 191.2151, Valid loss: 220.7425
# ==================================================
# Early Stopping!
# Best epoch is 12, training loss = 186.3444, minimum valid loss = 186.0739
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.1, 'weight_decay': 0.001}, 'patience': 5}
# Epoch 0, Train loss: 678.8418, Valid loss: 318.6826
# Epoch 1, Train loss: 248.1431, Valid loss: 199.5229
# Epoch 2, Train loss: 194.6995, Valid loss: 188.1755
# Epoch 3, Train loss: 187.2651, Valid loss: 186.5829
# Epoch 4, Train loss: 175.7446, Valid loss: 179.2298
# Epoch 5, Train loss: 166.8021, Valid loss: 168.3774
# Epoch 6, Train loss: 162.2331, Valid loss: 163.7708
# Epoch 7, Train loss: 164.6286, Valid loss: 167.749
# Epoch 8, Train loss: 155.3172, Valid loss: 148.5651
# Epoch 9, Train loss: 154.3931, Valid loss: 146.4695
# Epoch 10, Train loss: 155.9277, Valid loss: 156.9696
# Epoch 11, Train loss: 144.8104, Valid loss: 149.0069
# Epoch 12, Train loss: 140.192, Valid loss: 139.7396
# Epoch 13, Train loss: 134.8067, Valid loss: 141.7169
# Epoch 14, Train loss: 139.0389, Valid loss: 146.7333
# Epoch 15, Train loss: 132.1961, Valid loss: 136.7828
# Epoch 16, Train loss: 130.5175, Valid loss: 141.3919
# Epoch 17, Train loss: 126.6798, Valid loss: 146.369
# Epoch 18, Train loss: 141.9221, Valid loss: 138.208
# Epoch 19, Train loss: 142.0414, Valid loss: 156.4945
# ==================================================
# Model result:
# Best epoch is 15, training loss = 132.1961, minimum valid loss = 136.7828
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.1, 'weight_decay': 0.005}, 'patience': 5}
# Epoch 0, Train loss: 1609.7753, Valid loss: 1397.8162
# Epoch 1, Train loss: 692.6471, Valid loss: 517.6258
# Epoch 2, Train loss: 376.0872, Valid loss: 296.7475
# Epoch 3, Train loss: 244.6193, Valid loss: 221.5465
# Epoch 4, Train loss: 202.5134, Valid loss: 192.6279
# Epoch 5, Train loss: 180.6213, Valid loss: 201.2271
# Epoch 6, Train loss: 175.8779, Valid loss: 173.9838
# Epoch 7, Train loss: 174.6193, Valid loss: 170.0284
# Epoch 8, Train loss: 162.8722, Valid loss: 167.6501
# Epoch 9, Train loss: 164.6642, Valid loss: 164.3621
# Epoch 10, Train loss: 160.5515, Valid loss: 161.5676
# Epoch 11, Train loss: 158.2646, Valid loss: 162.1408
# Epoch 12, Train loss: 155.3444, Valid loss: 156.6871
# Epoch 13, Train loss: 149.6209, Valid loss: 153.8212
# Epoch 14, Train loss: 146.2057, Valid loss: 155.3027
# Epoch 15, Train loss: 144.5606, Valid loss: 149.5659
# Epoch 16, Train loss: 144.0432, Valid loss: 150.9591
# Epoch 17, Train loss: 145.8934, Valid loss: 145.3928
# Epoch 18, Train loss: 147.7167, Valid loss: 147.5019
# Epoch 19, Train loss: 140.4457, Valid loss: 148.4901
# ==================================================
# Model result:
# Best epoch is 17, training loss = 145.8934, minimum valid loss = 145.3928
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.1, 'weight_decay': 0.01}, 'patience': 5}
# Epoch 0, Train loss: 815.7164, Valid loss: 344.2301
# Epoch 1, Train loss: 290.1263, Valid loss: 222.0241
# Epoch 2, Train loss: 198.5632, Valid loss: 196.5525
# Epoch 3, Train loss: 179.2278, Valid loss: 171.2423
# Epoch 4, Train loss: 173.6886, Valid loss: 181.066
# Epoch 5, Train loss: 167.6954, Valid loss: 170.9556
# Epoch 6, Train loss: 164.3467, Valid loss: 164.7727
# Epoch 7, Train loss: 170.349, Valid loss: 179.4895
# Epoch 8, Train loss: 163.9996, Valid loss: 166.2773
# Epoch 9, Train loss: 152.4263, Valid loss: 151.1431
# Epoch 10, Train loss: 145.0192, Valid loss: 149.9649
# Epoch 11, Train loss: 146.0951, Valid loss: 180.8857
# Epoch 12, Train loss: 147.8237, Valid loss: 160.9438
# Epoch 13, Train loss: 143.6855, Valid loss: 163.6092
# Epoch 14, Train loss: 142.7609, Valid loss: 158.3869
# Epoch 15, Train loss: 138.2572, Valid loss: 143.9223
# Epoch 16, Train loss: 134.4721, Valid loss: 142.938
# Epoch 17, Train loss: 138.639, Valid loss: 136.9298
# Epoch 18, Train loss: 138.291, Valid loss: 153.6997
# Epoch 19, Train loss: 133.3533, Valid loss: 136.6685
# ==================================================
# Model result:
# Best epoch is 19, training loss = 133.3533, minimum valid loss = 136.6685
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.1, 'weight_decay': 0.05}, 'patience': 5}
# Epoch 0, Train loss: 1038.6867, Valid loss: 439.8621
# Epoch 1, Train loss: 326.4087, Valid loss: 257.8348
# Epoch 2, Train loss: 211.4721, Valid loss: 192.5
# Epoch 3, Train loss: 188.31, Valid loss: 192.0248
# Epoch 4, Train loss: 175.2601, Valid loss: 173.3768
# Epoch 5, Train loss: 168.7951, Valid loss: 168.8013
# Epoch 6, Train loss: 164.9073, Valid loss: 169.0597
# Epoch 7, Train loss: 156.8752, Valid loss: 163.8041
# Epoch 8, Train loss: 152.9469, Valid loss: 159.1496
# Epoch 9, Train loss: 145.7916, Valid loss: 162.53
# Epoch 10, Train loss: 143.914, Valid loss: 149.8533
# Epoch 11, Train loss: 138.0575, Valid loss: 149.0789
# Epoch 12, Train loss: 139.5343, Valid loss: 150.3766
# Epoch 13, Train loss: 138.4377, Valid loss: 141.0121
# Epoch 14, Train loss: 140.5156, Valid loss: 149.5852
# Epoch 15, Train loss: 137.4896, Valid loss: 137.8216
# Epoch 16, Train loss: 133.6783, Valid loss: 140.2429
# Epoch 17, Train loss: 141.5366, Valid loss: 140.0476
# Epoch 18, Train loss: 133.5713, Valid loss: 154.6648
# Epoch 19, Train loss: 135.1453, Valid loss: 138.7177
# ==================================================
# Model result:
# Best epoch is 15, training loss = 137.4896, minimum valid loss = 137.8216
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.1, 'weight_decay': 0.1}, 'patience': 5}
# Epoch 0, Train loss: 996.2001, Valid loss: 471.7487
# Epoch 1, Train loss: 296.6082, Valid loss: 250.6214
# Epoch 2, Train loss: 215.3801, Valid loss: 193.7711
# Epoch 3, Train loss: 178.3158, Valid loss: 174.2829
# Epoch 4, Train loss: 167.7543, Valid loss: 168.8172
# Epoch 5, Train loss: 162.4825, Valid loss: 175.0431
# Epoch 6, Train loss: 157.309, Valid loss: 159.0405
# Epoch 7, Train loss: 149.8367, Valid loss: 166.588
# Epoch 8, Train loss: 149.6097, Valid loss: 158.8611
# Epoch 9, Train loss: 145.7591, Valid loss: 156.205
# Epoch 10, Train loss: 152.4106, Valid loss: 141.5847
# Epoch 11, Train loss: 143.8812, Valid loss: 145.5286
# Epoch 12, Train loss: 135.6716, Valid loss: 153.4075
# Epoch 13, Train loss: 150.9379, Valid loss: 141.8645
# Epoch 14, Train loss: 137.2385, Valid loss: 143.112
# Epoch 15, Train loss: 147.8547, Valid loss: 137.7135
# Epoch 16, Train loss: 139.3115, Valid loss: 140.0267
# Epoch 17, Train loss: 144.5765, Valid loss: 149.8151
# Epoch 18, Train loss: 138.205, Valid loss: 139.4591
# Epoch 19, Train loss: 142.9992, Valid loss: 144.4051
# ==================================================
# Model result:
# Best epoch is 15, training loss = 147.8547, minimum valid loss = 137.7135
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.1, 'weight_decay': 1}, 'patience': 5}
# Epoch 0, Train loss: 1310.0228, Valid loss: 665.1872
# Epoch 1, Train loss: 575.191, Valid loss: 444.7824
# Epoch 2, Train loss: 324.3778, Valid loss: 228.2936
# Epoch 3, Train loss: 200.147, Valid loss: 188.2944
# Epoch 4, Train loss: 178.5096, Valid loss: 180.44
# Epoch 5, Train loss: 172.9312, Valid loss: 173.1817
# Epoch 6, Train loss: 166.0675, Valid loss: 171.461
# Epoch 7, Train loss: 162.8283, Valid loss: 167.1685
# Epoch 8, Train loss: 158.7943, Valid loss: 172.3657
# Epoch 9, Train loss: 163.4276, Valid loss: 162.9067
# Epoch 10, Train loss: 159.2273, Valid loss: 183.8249
# Epoch 11, Train loss: 162.692, Valid loss: 158.8601
# Epoch 12, Train loss: 153.4291, Valid loss: 168.5913
# Epoch 13, Train loss: 162.2262, Valid loss: 168.6909
# Epoch 14, Train loss: 154.5133, Valid loss: 161.9335
# Epoch 15, Train loss: 156.6283, Valid loss: 157.9414
# Epoch 16, Train loss: 148.5349, Valid loss: 151.1172
# Epoch 17, Train loss: 144.8722, Valid loss: 198.1697
# Epoch 18, Train loss: 179.717, Valid loss: 169.4737
# Epoch 19, Train loss: 157.1599, Valid loss: 167.8186
# ==================================================
# Model result:
# Best epoch is 16, training loss = 148.5349, minimum valid loss = 151.1172
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.1, 'weight_decay': 5}, 'patience': 5}
# Epoch 0, Train loss: 1023.8781, Valid loss: 409.0877
# Epoch 1, Train loss: 309.8002, Valid loss: 246.6194
# Epoch 2, Train loss: 211.9488, Valid loss: 202.4434
# Epoch 3, Train loss: 188.3365, Valid loss: 184.5834
# Epoch 4, Train loss: 192.2993, Valid loss: 189.7496
# Epoch 5, Train loss: 230.8996, Valid loss: 201.9445
# Epoch 6, Train loss: 226.2687, Valid loss: 190.106
# Epoch 7, Train loss: 190.0388, Valid loss: 184.3656
# Epoch 8, Train loss: 180.375, Valid loss: 180.746
# Epoch 9, Train loss: 190.4905, Valid loss: 208.79
# Epoch 10, Train loss: 179.6848, Valid loss: 188.3027
# Epoch 11, Train loss: 185.5348, Valid loss: 185.2562
# Epoch 12, Train loss: 187.5335, Valid loss: 218.5411
# Epoch 13, Train loss: 215.7907, Valid loss: 235.5323
# ==================================================
# Early Stopping!
# Best epoch is 8, training loss = 180.375, minimum valid loss = 180.746
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.1, 'weight_decay': 10}, 'patience': 5}
# Epoch 0, Train loss: 730.0142, Valid loss: 245.8184
# Epoch 1, Train loss: 202.6359, Valid loss: 239.4011
# Epoch 2, Train loss: 201.7301, Valid loss: 204.6695
# Epoch 3, Train loss: 225.1315, Valid loss: 252.8203
# Epoch 4, Train loss: 194.9755, Valid loss: 190.8715
# Epoch 5, Train loss: 191.3663, Valid loss: 266.2352
# Epoch 6, Train loss: 203.9106, Valid loss: 189.5086
# Epoch 7, Train loss: 185.5804, Valid loss: 194.3859
# Epoch 8, Train loss: 193.539, Valid loss: 229.1027
# Epoch 9, Train loss: 188.1566, Valid loss: 190.025
# Epoch 10, Train loss: 185.6729, Valid loss: 198.4562
# Epoch 11, Train loss: 185.3049, Valid loss: 185.8472
# Epoch 12, Train loss: 205.6738, Valid loss: 213.9232
# Epoch 13, Train loss: 196.4625, Valid loss: 186.4347
# Epoch 14, Train loss: 210.0398, Valid loss: 183.3539
# Epoch 15, Train loss: 194.3513, Valid loss: 209.0733
# Epoch 16, Train loss: 215.8995, Valid loss: 251.942
# Epoch 17, Train loss: 210.1333, Valid loss: 249.8008
# Epoch 18, Train loss: 198.6757, Valid loss: 185.7115
# Epoch 19, Train loss: 191.0443, Valid loss: 269.2858
# ==================================================
# Early Stopping!
# Best epoch is 14, training loss = 210.0398, minimum valid loss = 183.3539
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.05, 'weight_decay': 0.001}, 'patience': 5}
# Epoch 0, Train loss: 1492.3359, Valid loss: 591.1948
# Epoch 1, Train loss: 482.0691, Valid loss: 395.576
# Epoch 2, Train loss: 297.0517, Valid loss: 258.7773
# Epoch 3, Train loss: 212.8494, Valid loss: 192.6939
# Epoch 4, Train loss: 182.7675, Valid loss: 180.4289
# Epoch 5, Train loss: 168.6266, Valid loss: 166.9823
# Epoch 6, Train loss: 162.4994, Valid loss: 160.5437
# Epoch 7, Train loss: 155.3902, Valid loss: 163.0548
# Epoch 8, Train loss: 153.6667, Valid loss: 159.2633
# Epoch 9, Train loss: 148.6208, Valid loss: 156.0322
# Epoch 10, Train loss: 145.0557, Valid loss: 146.6691
# Epoch 11, Train loss: 137.2808, Valid loss: 144.2121
# Epoch 12, Train loss: 137.8845, Valid loss: 147.3179
# Epoch 13, Train loss: 135.3326, Valid loss: 141.3222
# Epoch 14, Train loss: 134.1193, Valid loss: 142.6579
# Epoch 15, Train loss: 131.4225, Valid loss: 139.1274
# Epoch 16, Train loss: 132.5881, Valid loss: 146.0524
# Epoch 17, Train loss: 134.8438, Valid loss: 142.2914
# Epoch 18, Train loss: 131.1655, Valid loss: 137.7831
# Epoch 19, Train loss: 131.3667, Valid loss: 139.3557
# ==================================================
# Model result:
# Best epoch is 18, training loss = 131.1655, minimum valid loss = 137.7831
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.05, 'weight_decay': 0.005}, 'patience': 5}
# Epoch 0, Train loss: 1098.2779, Valid loss: 543.7686
# Epoch 1, Train loss: 381.3496, Valid loss: 284.1734
# Epoch 2, Train loss: 245.8072, Valid loss: 218.2743
# Epoch 3, Train loss: 206.5366, Valid loss: 241.76
# Epoch 4, Train loss: 196.1229, Valid loss: 179.5991
# Epoch 5, Train loss: 182.3225, Valid loss: 174.3025
# Epoch 6, Train loss: 169.2833, Valid loss: 173.9014
# Epoch 7, Train loss: 162.8632, Valid loss: 165.3468
# Epoch 8, Train loss: 159.0125, Valid loss: 164.7355
# Epoch 9, Train loss: 156.1456, Valid loss: 161.6416
# Epoch 10, Train loss: 153.3241, Valid loss: 180.892
# Epoch 11, Train loss: 158.2489, Valid loss: 160.3974
# Epoch 12, Train loss: 147.3827, Valid loss: 152.8837
# Epoch 13, Train loss: 148.6582, Valid loss: 148.1659
# Epoch 14, Train loss: 145.8971, Valid loss: 149.8181
# Epoch 15, Train loss: 147.2962, Valid loss: 155.0802
# Epoch 16, Train loss: 140.8031, Valid loss: 143.5639
# Epoch 17, Train loss: 134.7098, Valid loss: 143.9682
# Epoch 18, Train loss: 135.0996, Valid loss: 143.9191
# Epoch 19, Train loss: 137.4841, Valid loss: 141.1075
# ==================================================
# Model result:
# Best epoch is 19, training loss = 137.4841, minimum valid loss = 141.1075
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.05, 'weight_decay': 0.01}, 'patience': 5}
# Epoch 0, Train loss: 929.2265, Valid loss: 383.8772
# Epoch 1, Train loss: 298.111, Valid loss: 286.0114
# Epoch 2, Train loss: 218.5508, Valid loss: 193.7599
# Epoch 3, Train loss: 180.1923, Valid loss: 173.5241
# Epoch 4, Train loss: 169.1272, Valid loss: 170.8389
# Epoch 5, Train loss: 162.4741, Valid loss: 180.7243
# Epoch 6, Train loss: 164.6086, Valid loss: 170.0927
# Epoch 7, Train loss: 158.8436, Valid loss: 158.5139
# Epoch 8, Train loss: 151.495, Valid loss: 152.0806
# Epoch 9, Train loss: 152.8683, Valid loss: 151.7185
# Epoch 10, Train loss: 144.6462, Valid loss: 145.066
# Epoch 11, Train loss: 138.0174, Valid loss: 144.3003
# Epoch 12, Train loss: 134.2925, Valid loss: 146.4565
# Epoch 13, Train loss: 137.6653, Valid loss: 146.9401
# Epoch 14, Train loss: 136.1339, Valid loss: 138.8961
# Epoch 15, Train loss: 132.6583, Valid loss: 139.6669
# Epoch 16, Train loss: 135.2468, Valid loss: 139.3937
# Epoch 17, Train loss: 136.7879, Valid loss: 142.1013
# Epoch 18, Train loss: 131.0023, Valid loss: 139.563
# Epoch 19, Train loss: 129.7928, Valid loss: 134.6713
# ==================================================
# Model result:
# Best epoch is 19, training loss = 129.7928, minimum valid loss = 134.6713
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.05, 'weight_decay': 0.05}, 'patience': 5}
# Epoch 0, Train loss: 2148.4541, Valid loss: 2252.753
# Epoch 1, Train loss: 2097.5457, Valid loss: 2203.0053
# Epoch 2, Train loss: 2049.7271, Valid loss: 2154.436
# Epoch 3, Train loss: 2002.9227, Valid loss: 2107.1425
# Epoch 4, Train loss: 1957.4969, Valid loss: 2060.9952
# Epoch 5, Train loss: 1913.2909, Valid loss: 2015.949
# Epoch 6, Train loss: 1870.2402, Valid loss: 1972.1184
# Epoch 7, Train loss: 1828.0684, Valid loss: 1929.7749
# Epoch 8, Train loss: 1787.4728, Valid loss: 1888.3264
# Epoch 9, Train loss: 1747.8243, Valid loss: 1848.0363
# Epoch 10, Train loss: 1709.3468, Valid loss: 1808.7973
# Epoch 11, Train loss: 1671.7813, Valid loss: 1770.8124
# Epoch 12, Train loss: 1635.481, Valid loss: 1733.8032
# Epoch 13, Train loss: 1600.2648, Valid loss: 1697.7574
# Epoch 14, Train loss: 1565.7423, Valid loss: 1663.088
# Epoch 15, Train loss: 1532.7475, Valid loss: 1629.1063
# Epoch 16, Train loss: 1500.4884, Valid loss: 1596.1251
# Epoch 17, Train loss: 1469.1123, Valid loss: 1564.239
# Epoch 18, Train loss: 1438.7841, Valid loss: 1533.3165
# Epoch 19, Train loss: 1409.4136, Valid loss: 1503.3051
# ==================================================
# Model result:
# Best epoch is 19, training loss = 1409.4136, minimum valid loss = 1503.3051
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.05, 'weight_decay': 0.1}, 'patience': 5}
# Epoch 0, Train loss: 1859.8874, Valid loss: 1048.8055
# Epoch 1, Train loss: 642.6864, Valid loss: 426.2068
# Epoch 2, Train loss: 348.2386, Valid loss: 271.2207
# Epoch 3, Train loss: 231.359, Valid loss: 210.9389
# Epoch 4, Train loss: 203.3608, Valid loss: 211.5274
# Epoch 5, Train loss: 189.4826, Valid loss: 182.5228
# Epoch 6, Train loss: 177.8517, Valid loss: 180.4898
# Epoch 7, Train loss: 173.6238, Valid loss: 176.6348
# Epoch 8, Train loss: 171.8084, Valid loss: 175.7809
# Epoch 9, Train loss: 170.2438, Valid loss: 172.1465
# Epoch 10, Train loss: 168.0385, Valid loss: 177.7056
# Epoch 11, Train loss: 168.8743, Valid loss: 173.9742
# Epoch 12, Train loss: 165.453, Valid loss: 176.946
# Epoch 13, Train loss: 160.8896, Valid loss: 161.9031
# Epoch 14, Train loss: 157.1862, Valid loss: 157.4782
# Epoch 15, Train loss: 152.43, Valid loss: 157.6381
# Epoch 16, Train loss: 154.682, Valid loss: 179.9976
# Epoch 17, Train loss: 158.4958, Valid loss: 156.9132
# Epoch 18, Train loss: 151.5861, Valid loss: 152.7645
# Epoch 19, Train loss: 142.7701, Valid loss: 153.527
# ==================================================
# Model result:
# Best epoch is 18, training loss = 151.5861, minimum valid loss = 152.7645
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.05, 'weight_decay': 1}, 'patience': 5}
# Epoch 0, Train loss: 1247.6914, Valid loss: 607.3316
# Epoch 1, Train loss: 462.7602, Valid loss: 329.8712
# Epoch 2, Train loss: 265.5119, Valid loss: 233.7599
# Epoch 3, Train loss: 198.7722, Valid loss: 185.7957
# Epoch 4, Train loss: 187.9328, Valid loss: 214.4725
# Epoch 5, Train loss: 178.774, Valid loss: 177.8122
# Epoch 6, Train loss: 166.3677, Valid loss: 175.051
# Epoch 7, Train loss: 172.1846, Valid loss: 181.9421
# Epoch 8, Train loss: 170.2553, Valid loss: 171.4845
# Epoch 9, Train loss: 169.3407, Valid loss: 177.1893
# Epoch 10, Train loss: 160.014, Valid loss: 161.0554
# Epoch 11, Train loss: 156.8398, Valid loss: 156.4822
# Epoch 12, Train loss: 163.9276, Valid loss: 178.2002
# Epoch 13, Train loss: 153.0817, Valid loss: 153.6719
# Epoch 14, Train loss: 146.2201, Valid loss: 149.5165
# Epoch 15, Train loss: 158.3731, Valid loss: 152.838
# Epoch 16, Train loss: 162.4263, Valid loss: 185.7364
# Epoch 17, Train loss: 151.9067, Valid loss: 157.907
# Epoch 18, Train loss: 145.3429, Valid loss: 159.5147
# Epoch 19, Train loss: 144.8953, Valid loss: 155.9539
# ==================================================
# Early Stopping!
# Best epoch is 14, training loss = 146.2201, minimum valid loss = 149.5165
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.05, 'weight_decay': 5}, 'patience': 5}
# Epoch 0, Train loss: 1201.8923, Valid loss: 626.841
# Epoch 1, Train loss: 440.311, Valid loss: 335.5435
# Epoch 2, Train loss: 255.1161, Valid loss: 218.2906
# Epoch 3, Train loss: 190.9608, Valid loss: 188.4432
# Epoch 4, Train loss: 178.5846, Valid loss: 181.9128
# Epoch 5, Train loss: 179.7333, Valid loss: 192.3214
# Epoch 6, Train loss: 188.3856, Valid loss: 226.7545
# Epoch 7, Train loss: 212.6459, Valid loss: 206.9829
# Epoch 8, Train loss: 205.0799, Valid loss: 183.8201
# Epoch 9, Train loss: 192.1207, Valid loss: 233.449
# ==================================================
# Early Stopping!
# Best epoch is 4, training loss = 178.5846, minimum valid loss = 181.9128
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.05, 'weight_decay': 10}, 'patience': 5}
# Epoch 0, Train loss: 1465.2377, Valid loss: 619.835
# Epoch 1, Train loss: 459.8354, Valid loss: 296.2396
# Epoch 2, Train loss: 230.1416, Valid loss: 231.0076
# Epoch 3, Train loss: 196.6865, Valid loss: 195.4653
# Epoch 4, Train loss: 185.334, Valid loss: 224.3182
# Epoch 5, Train loss: 189.3496, Valid loss: 204.4297
# Epoch 6, Train loss: 183.1169, Valid loss: 198.5363
# Epoch 7, Train loss: 202.8432, Valid loss: 200.3009
# Epoch 8, Train loss: 195.8664, Valid loss: 243.251
# ==================================================
# Early Stopping!
# Best epoch is 3, training loss = 196.6865, minimum valid loss = 195.4653
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.01, 'weight_decay': 0.001}, 'patience': 5}
# Epoch 0, Train loss: 1865.4261, Valid loss: 1340.4258
# Epoch 1, Train loss: 862.9439, Valid loss: 686.2292
# Epoch 2, Train loss: 538.8156, Valid loss: 429.0398
# Epoch 3, Train loss: 381.201, Valid loss: 312.6894
# Epoch 4, Train loss: 275.8548, Valid loss: 253.149
# Epoch 5, Train loss: 233.7908, Valid loss: 224.2345
# Epoch 6, Train loss: 209.6875, Valid loss: 204.0751
# Epoch 7, Train loss: 194.7414, Valid loss: 195.3161
# Epoch 8, Train loss: 183.8959, Valid loss: 181.7349
# Epoch 9, Train loss: 176.6549, Valid loss: 177.6831
# Epoch 10, Train loss: 170.6853, Valid loss: 174.3466
# Epoch 11, Train loss: 168.1406, Valid loss: 169.6416
# Epoch 12, Train loss: 166.4771, Valid loss: 171.0466
# Epoch 13, Train loss: 164.3514, Valid loss: 166.7165
# Epoch 14, Train loss: 159.9801, Valid loss: 169.6396
# Epoch 15, Train loss: 162.6426, Valid loss: 160.5608
# Epoch 16, Train loss: 156.5615, Valid loss: 163.678
# Epoch 17, Train loss: 154.6803, Valid loss: 158.0688
# Epoch 18, Train loss: 152.2311, Valid loss: 156.6558
# Epoch 19, Train loss: 150.0543, Valid loss: 160.2509
# ==================================================
# Model result:
# Best epoch is 18, training loss = 152.2311, minimum valid loss = 156.6558
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.01, 'weight_decay': 0.005}, 'patience': 5}
# Epoch 0, Train loss: 1405.3396, Valid loss: 650.753
# Epoch 1, Train loss: 568.3768, Valid loss: 447.1679
# Epoch 2, Train loss: 389.2627, Valid loss: 344.2769
# Epoch 3, Train loss: 300.8229, Valid loss: 284.6214
# Epoch 4, Train loss: 249.5465, Valid loss: 233.8536
# Epoch 5, Train loss: 211.6316, Valid loss: 211.645
# Epoch 6, Train loss: 195.9959, Valid loss: 195.1384
# Epoch 7, Train loss: 185.5282, Valid loss: 187.5513
# Epoch 8, Train loss: 180.3852, Valid loss: 190.2953
# Epoch 9, Train loss: 173.8961, Valid loss: 177.4617
# Epoch 10, Train loss: 172.8349, Valid loss: 175.1451
# Epoch 11, Train loss: 173.1514, Valid loss: 181.5374
# Epoch 12, Train loss: 170.6718, Valid loss: 176.9705
# Epoch 13, Train loss: 169.5755, Valid loss: 170.4918
# Epoch 14, Train loss: 168.2875, Valid loss: 180.0985
# Epoch 15, Train loss: 165.1571, Valid loss: 168.1077
# Epoch 16, Train loss: 163.517, Valid loss: 167.2659
# Epoch 17, Train loss: 160.0389, Valid loss: 166.9657
# Epoch 18, Train loss: 158.3459, Valid loss: 162.5042
# Epoch 19, Train loss: 153.314, Valid loss: 160.455
# ==================================================
# Model result:
# Best epoch is 19, training loss = 153.314, minimum valid loss = 160.455
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.01, 'weight_decay': 0.01}, 'patience': 5}
# Epoch 0, Train loss: 1659.0575, Valid loss: 820.6543
# Epoch 1, Train loss: 683.0696, Valid loss: 532.4437
# Epoch 2, Train loss: 469.1638, Valid loss: 401.3202
# Epoch 3, Train loss: 350.1007, Valid loss: 305.8142
# Epoch 4, Train loss: 273.2442, Valid loss: 259.0459
# Epoch 5, Train loss: 231.2529, Valid loss: 222.9574
# Epoch 6, Train loss: 209.729, Valid loss: 207.8926
# Epoch 7, Train loss: 197.2415, Valid loss: 196.9214
# Epoch 8, Train loss: 190.5895, Valid loss: 190.1313
# Epoch 9, Train loss: 184.5085, Valid loss: 186.3479
# Epoch 10, Train loss: 181.6592, Valid loss: 184.7324
# Epoch 11, Train loss: 179.5654, Valid loss: 186.729
# Epoch 12, Train loss: 177.0567, Valid loss: 181.9543
# Epoch 13, Train loss: 175.4918, Valid loss: 180.5687
# Epoch 14, Train loss: 173.6845, Valid loss: 179.1812
# Epoch 15, Train loss: 173.5213, Valid loss: 184.402
# Epoch 16, Train loss: 173.9454, Valid loss: 178.4405
# Epoch 17, Train loss: 170.0541, Valid loss: 175.6795
# Epoch 18, Train loss: 168.2497, Valid loss: 172.6239
# Epoch 19, Train loss: 168.2434, Valid loss: 183.7327
# ==================================================
# Model result:
# Best epoch is 18, training loss = 168.2497, minimum valid loss = 172.6239
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.01, 'weight_decay': 0.05}, 'patience': 5}
# Epoch 0, Train loss: 1908.914, Valid loss: 1493.3411
# Epoch 1, Train loss: 930.6428, Valid loss: 813.3278
# Epoch 2, Train loss: 630.1106, Valid loss: 541.3112
# Epoch 3, Train loss: 453.7054, Valid loss: 397.4689
# Epoch 4, Train loss: 354.9119, Valid loss: 310.7437
# Epoch 5, Train loss: 279.3278, Valid loss: 260.0345
# Epoch 6, Train loss: 234.6068, Valid loss: 229.6197
# Epoch 7, Train loss: 209.7204, Valid loss: 203.985
# Epoch 8, Train loss: 190.4374, Valid loss: 189.632
# Epoch 9, Train loss: 180.423, Valid loss: 182.9443
# Epoch 10, Train loss: 175.1559, Valid loss: 180.1357
# Epoch 11, Train loss: 170.782, Valid loss: 177.0127
# Epoch 12, Train loss: 168.7828, Valid loss: 172.5636
# Epoch 13, Train loss: 167.8242, Valid loss: 175.6467
# Epoch 14, Train loss: 167.4247, Valid loss: 171.7539
# Epoch 15, Train loss: 164.0523, Valid loss: 168.4912
# Epoch 16, Train loss: 161.303, Valid loss: 168.3041
# Epoch 17, Train loss: 161.9892, Valid loss: 168.3803
# Epoch 18, Train loss: 158.312, Valid loss: 165.6133
# Epoch 19, Train loss: 155.2338, Valid loss: 161.59
# ==================================================
# Model result:
# Best epoch is 19, training loss = 155.2338, minimum valid loss = 161.59
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.01, 'weight_decay': 0.1}, 'patience': 5}
# Epoch 0, Train loss: 1688.1726, Valid loss: 937.1322
# Epoch 1, Train loss: 721.828, Valid loss: 572.2637
# Epoch 2, Train loss: 501.7104, Valid loss: 414.7076
# Epoch 3, Train loss: 376.9969, Valid loss: 335.5414
# Epoch 4, Train loss: 293.7385, Valid loss: 268.9832
# Epoch 5, Train loss: 241.128, Valid loss: 232.9789
# Epoch 6, Train loss: 212.3433, Valid loss: 206.4234
# Epoch 7, Train loss: 196.6334, Valid loss: 192.745
# Epoch 8, Train loss: 184.0219, Valid loss: 182.1468
# Epoch 9, Train loss: 176.1085, Valid loss: 175.9592
# Epoch 10, Train loss: 169.8393, Valid loss: 172.3091
# Epoch 11, Train loss: 165.2843, Valid loss: 167.7217
# Epoch 12, Train loss: 163.5699, Valid loss: 168.0234
# Epoch 13, Train loss: 160.3438, Valid loss: 163.8585
# Epoch 14, Train loss: 157.501, Valid loss: 160.3113
# Epoch 15, Train loss: 154.368, Valid loss: 156.9302
# Epoch 16, Train loss: 151.3551, Valid loss: 155.1022
# Epoch 17, Train loss: 148.0242, Valid loss: 153.8906
# Epoch 18, Train loss: 145.7263, Valid loss: 148.652
# Epoch 19, Train loss: 143.2803, Valid loss: 146.7766
# ==================================================
# Model result:
# Best epoch is 19, training loss = 143.2803, minimum valid loss = 146.7766
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.01, 'weight_decay': 1}, 'patience': 5}
# Epoch 0, Train loss: 1881.9208, Valid loss: 1431.5673
# Epoch 1, Train loss: 902.9928, Valid loss: 824.5563
# Epoch 2, Train loss: 627.5154, Valid loss: 555.8436
# Epoch 3, Train loss: 466.034, Valid loss: 400.4708
# Epoch 4, Train loss: 352.5883, Valid loss: 314.7487
# Epoch 5, Train loss: 279.0595, Valid loss: 261.8381
# Epoch 6, Train loss: 231.7104, Valid loss: 217.3961
# Epoch 7, Train loss: 201.1556, Valid loss: 193.3511
# Epoch 8, Train loss: 186.6328, Valid loss: 184.2627
# Epoch 9, Train loss: 177.1987, Valid loss: 179.5832
# Epoch 10, Train loss: 171.5916, Valid loss: 173.4775
# Epoch 11, Train loss: 168.5793, Valid loss: 173.1501
# Epoch 12, Train loss: 165.1368, Valid loss: 169.2991
# Epoch 13, Train loss: 162.2212, Valid loss: 168.043
# Epoch 14, Train loss: 164.7287, Valid loss: 167.9605
# Epoch 15, Train loss: 160.7838, Valid loss: 176.8052
# Epoch 16, Train loss: 157.3725, Valid loss: 166.8417
# Epoch 17, Train loss: 156.6532, Valid loss: 158.6615
# Epoch 18, Train loss: 154.102, Valid loss: 165.2159
# Epoch 19, Train loss: 152.4715, Valid loss: 157.1064
# ==================================================
# Model result:
# Best epoch is 19, training loss = 152.4715, minimum valid loss = 157.1064
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.01, 'weight_decay': 5}, 'patience': 5}
# Epoch 0, Train loss: 1708.6449, Valid loss: 974.0381
# Epoch 1, Train loss: 760.9711, Valid loss: 597.5331
# Epoch 2, Train loss: 521.0605, Valid loss: 419.2759
# Epoch 3, Train loss: 379.5967, Valid loss: 331.7146
# Epoch 4, Train loss: 276.9444, Valid loss: 254.0827
# Epoch 5, Train loss: 227.5638, Valid loss: 228.1728
# Epoch 6, Train loss: 202.6177, Valid loss: 194.864
# Epoch 7, Train loss: 185.4525, Valid loss: 189.3957
# Epoch 8, Train loss: 179.3403, Valid loss: 183.8353
# Epoch 9, Train loss: 177.9759, Valid loss: 183.7998
# Epoch 10, Train loss: 176.0643, Valid loss: 182.1457
# Epoch 11, Train loss: 175.4835, Valid loss: 183.8417
# Epoch 12, Train loss: 174.4744, Valid loss: 180.7871
# Epoch 13, Train loss: 174.171, Valid loss: 181.1912
# Epoch 14, Train loss: 174.7176, Valid loss: 188.8189
# Epoch 15, Train loss: 177.943, Valid loss: 191.8322
# Epoch 16, Train loss: 176.8474, Valid loss: 185.4814
# Epoch 17, Train loss: 175.6727, Valid loss: 181.9647
# ==================================================
# Early Stopping!
# Best epoch is 12, training loss = 174.4744, minimum valid loss = 180.7871
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.01, 'weight_decay': 10}, 'patience': 5}
# Epoch 0, Train loss: 1718.9689, Valid loss: 973.106
# Epoch 1, Train loss: 679.9133, Valid loss: 517.927
# Epoch 2, Train loss: 464.4894, Valid loss: 387.0502
# Epoch 3, Train loss: 335.7398, Valid loss: 295.0462
# Epoch 4, Train loss: 259.9053, Valid loss: 231.826
# Epoch 5, Train loss: 209.8588, Valid loss: 204.1524
# Epoch 6, Train loss: 195.7967, Valid loss: 192.6458
# Epoch 7, Train loss: 181.6623, Valid loss: 185.6438
# Epoch 8, Train loss: 178.1469, Valid loss: 184.0685
# Epoch 9, Train loss: 176.9719, Valid loss: 184.1492
# Epoch 10, Train loss: 176.5238, Valid loss: 184.1397
# Epoch 11, Train loss: 177.2349, Valid loss: 184.523
# Epoch 12, Train loss: 182.8189, Valid loss: 186.2735
# Epoch 13, Train loss: 182.5621, Valid loss: 182.7658
# Epoch 14, Train loss: 176.9576, Valid loss: 194.5026
# Epoch 15, Train loss: 177.9101, Valid loss: 186.6034
# Epoch 16, Train loss: 180.4915, Valid loss: 198.3895
# Epoch 17, Train loss: 178.0223, Valid loss: 183.9108
# Epoch 18, Train loss: 175.2082, Valid loss: 184.7741
# ==================================================
# Early Stopping!
# Best epoch is 13, training loss = 182.5621, minimum valid loss = 182.7658
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.005, 'weight_decay': 0.001}, 'patience': 5}
# Epoch 0, Train loss: 2005.6847, Valid loss: 1849.3285
# Epoch 1, Train loss: 1420.9304, Valid loss: 1029.9905
# Epoch 2, Train loss: 816.9938, Valid loss: 752.4257
# Epoch 3, Train loss: 649.7634, Valid loss: 598.8447
# Epoch 4, Train loss: 544.8859, Valid loss: 492.1995
# Epoch 5, Train loss: 440.8647, Valid loss: 394.7594
# Epoch 6, Train loss: 356.5193, Valid loss: 326.9295
# Epoch 7, Train loss: 296.1279, Valid loss: 283.029
# Epoch 8, Train loss: 257.3533, Valid loss: 251.8904
# Epoch 9, Train loss: 231.3465, Valid loss: 226.8997
# Epoch 10, Train loss: 212.116, Valid loss: 209.1936
# Epoch 11, Train loss: 199.634, Valid loss: 197.1451
# Epoch 12, Train loss: 192.6763, Valid loss: 191.4174
# Epoch 13, Train loss: 187.4481, Valid loss: 185.0891
# Epoch 14, Train loss: 178.9927, Valid loss: 180.4705
# Epoch 15, Train loss: 173.2039, Valid loss: 177.336
# Epoch 16, Train loss: 170.6409, Valid loss: 174.7507
# Epoch 17, Train loss: 168.4346, Valid loss: 174.1589
# Epoch 18, Train loss: 166.3365, Valid loss: 172.2264
# Epoch 19, Train loss: 165.1996, Valid loss: 168.7604
# ==================================================
# Model result:
# Best epoch is 19, training loss = 165.1996, minimum valid loss = 168.7604
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.005, 'weight_decay': 0.005}, 'patience': 5}
# Epoch 0, Train loss: 1821.0375, Valid loss: 1537.3994
# Epoch 1, Train loss: 1039.1029, Valid loss: 742.6199
# Epoch 2, Train loss: 673.1335, Valid loss: 599.3852
# Epoch 3, Train loss: 515.9742, Valid loss: 455.9534
# Epoch 4, Train loss: 400.7669, Valid loss: 357.8163
# Epoch 5, Train loss: 317.0653, Valid loss: 301.3287
# Epoch 6, Train loss: 271.039, Valid loss: 269.1151
# Epoch 7, Train loss: 239.9007, Valid loss: 237.0952
# Epoch 8, Train loss: 216.4818, Valid loss: 215.135
# Epoch 9, Train loss: 201.285, Valid loss: 201.7274
# Epoch 10, Train loss: 189.5829, Valid loss: 194.6834
# Epoch 11, Train loss: 185.2757, Valid loss: 194.1083
# Epoch 12, Train loss: 180.1597, Valid loss: 185.6591
# Epoch 13, Train loss: 175.0382, Valid loss: 181.5574
# Epoch 14, Train loss: 173.2468, Valid loss: 180.1898
# Epoch 15, Train loss: 169.6468, Valid loss: 176.4313
# Epoch 16, Train loss: 167.6898, Valid loss: 178.0683
# Epoch 17, Train loss: 166.4695, Valid loss: 173.3472
# Epoch 18, Train loss: 164.0412, Valid loss: 170.8177
# Epoch 19, Train loss: 162.6637, Valid loss: 169.6928
# ==================================================
# Model result:
# Best epoch is 19, training loss = 162.6637, minimum valid loss = 169.6928
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.005, 'weight_decay': 0.01}, 'patience': 5}
# Epoch 0, Train loss: 2154.2818, Valid loss: 2244.7964
# Epoch 1, Train loss: 2013.2257, Valid loss: 1936.635
# Epoch 2, Train loss: 1488.0837, Valid loss: 1055.5695
# Epoch 3, Train loss: 738.2604, Valid loss: 690.2827
# Epoch 4, Train loss: 573.1521, Valid loss: 516.7929
# Epoch 5, Train loss: 460.8439, Valid loss: 419.8348
# Epoch 6, Train loss: 389.1289, Valid loss: 357.5181
# Epoch 7, Train loss: 332.0186, Valid loss: 311.0646
# Epoch 8, Train loss: 287.3044, Valid loss: 280.8941
# Epoch 9, Train loss: 260.5879, Valid loss: 256.3059
# Epoch 10, Train loss: 237.9597, Valid loss: 234.5269
# Epoch 11, Train loss: 221.3447, Valid loss: 217.9462
# Epoch 12, Train loss: 207.2819, Valid loss: 207.9922
# Epoch 13, Train loss: 197.5326, Valid loss: 197.2621
# Epoch 14, Train loss: 190.0816, Valid loss: 194.6051
# Epoch 15, Train loss: 186.1142, Valid loss: 187.5846
# Epoch 16, Train loss: 181.7388, Valid loss: 184.3726
# Epoch 17, Train loss: 177.3995, Valid loss: 182.2081
# Epoch 18, Train loss: 175.044, Valid loss: 178.2973
# Epoch 19, Train loss: 171.2753, Valid loss: 182.4696
# ==================================================
# Model result:
# Best epoch is 18, training loss = 175.044, minimum valid loss = 178.2973
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 20, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.005, 'weight_decay': 0.05}, 'patience': 5}
# Epoch 0, Train loss: 1964.0658, Valid loss: 1770.6358
# Epoch 1, Train loss: 1277.5535, Valid loss: 823.9388
# Epoch 2, Train loss: 714.0526, Valid loss: 694.8777
# Epoch 3, Train loss: 591.8423, Valid loss: 542.4999
# Epoch 4, Train loss: 477.6064, Valid loss: 432.7786
# Epoch 5, Train loss: 396.1621, Valid loss: 364.5238
# Epoch 6, Train loss: 331.2308, Valid loss: 312.6418
# Epoch 7, Train loss: 288.3529, Valid loss: 281.0469
# Epoch 8, Train loss: 255.5478, Valid loss: 253.4816
# Epoch 9, Train loss: 233.8104, Valid loss: 230.7003
# Epoch 10, Train loss: 215.0725, Valid loss: 214.262
# Epoch 11, Train loss: 200.5738, Valid loss: 202.8417
# Epoch 12, Train loss: 190.6747, Valid loss: 191.7888
# Epoch 13, Train loss: 182.3015, Valid loss: 185.222
# Epoch 14, Train loss: 176.4858, Valid loss: 180.0422
# Epoch 15, Train loss: 172.875, Valid loss: 176.0485
# Epoch 16, Train loss: 168.2437, Valid loss: 172.5974
# Epoch 17, Train loss: 165.3607, Valid loss: 169.2652
# Epoch 18, Train loss: 164.4379, Valid loss: 169.0496
# Epoch 19, Train loss: 161.6487, Valid loss: 165.8567
# ==================================================
# Model result:
# Best epoch is 19, training loss = 161.6487, minimum valid loss = 165.8567
# ==================================================
# Parameter settings:
# ...
# Epoch 32, Train loss: 150.5206, Valid loss: 161.0285
# Epoch 33, Train loss: 150.4967, Valid loss: 156.9574
# Epoch 34, Train loss: 148.7727, Valid loss: 156.7574
# Epoch 35, Train loss: 147.6104, Valid loss: 155.0086
# Epoch 36, Train loss: 145.2322, Valid loss: 155.596
# Epoch 37, Train loss: 144.7418, Valid loss: 153.641
# Epoch 38, Train loss: 144.1295, Valid loss: 152.1009
# Epoch 39, Train loss: 143.2293, Valid loss: 153.1191
# Epoch 40, Train loss: 141.967, Valid loss: 151.0986
# Epoch 41, Train loss: 141.0179, Valid loss: 150.0139
# Epoch 42, Train loss: 140.7404, Valid loss: 149.772
# Epoch 43, Train loss: 139.4096, Valid loss: 149.9177
# Epoch 44, Train loss: 139.0634, Valid loss: 147.897
# Epoch 45, Train loss: 139.1169, Valid loss: 149.3949
# Epoch 46, Train loss: 139.1455, Valid loss: 147.0029
# Epoch 47, Train loss: 138.9848, Valid loss: 150.199
# Epoch 48, Train loss: 138.5232, Valid loss: 145.9436
# Epoch 49, Train loss: 136.4628, Valid loss: 147.0756
# ==================================================
# Model result:
# Best epoch is 48, training loss = 138.5232, minimum valid loss = 145.9436
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 50, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.005, 'weight_decay': 0.05}, 'patience': 15}
# Epoch 0, Train loss: 2022.0439, Valid loss: 1912.2431
# Epoch 1, Train loss: 1404.7692, Valid loss: 896.833
# Epoch 2, Train loss: 689.0574, Valid loss: 623.5718
# Epoch 3, Train loss: 515.3701, Valid loss: 466.237
# Epoch 4, Train loss: 405.9162, Valid loss: 383.7763
# Epoch 5, Train loss: 346.6786, Valid loss: 323.135
# Epoch 6, Train loss: 292.2987, Valid loss: 281.871
# Epoch 7, Train loss: 257.288, Valid loss: 251.7857
# Epoch 8, Train loss: 232.2196, Valid loss: 226.5022
# Epoch 9, Train loss: 213.2532, Valid loss: 211.1921
# Epoch 10, Train loss: 201.8695, Valid loss: 201.1537
# Epoch 11, Train loss: 194.2064, Valid loss: 195.2039
# Epoch 12, Train loss: 189.1036, Valid loss: 190.7277
# Epoch 13, Train loss: 185.5905, Valid loss: 188.2664
# Epoch 14, Train loss: 183.3387, Valid loss: 185.7041
# Epoch 15, Train loss: 181.2884, Valid loss: 185.1331
# Epoch 16, Train loss: 179.4145, Valid loss: 184.7642
# Epoch 17, Train loss: 178.9912, Valid loss: 182.3258
# Epoch 18, Train loss: 176.8946, Valid loss: 181.8766
# Epoch 19, Train loss: 176.7579, Valid loss: 181.2663
# Epoch 20, Train loss: 175.251, Valid loss: 180.7797
# Epoch 21, Train loss: 173.3318, Valid loss: 181.8172
# Epoch 22, Train loss: 173.3699, Valid loss: 179.1299
# Epoch 23, Train loss: 172.6406, Valid loss: 179.5956
# Epoch 24, Train loss: 172.2517, Valid loss: 178.0432
# Epoch 25, Train loss: 171.8378, Valid loss: 177.5284
# Epoch 26, Train loss: 171.9534, Valid loss: 178.1146
# Epoch 27, Train loss: 171.1784, Valid loss: 178.3219
# Epoch 28, Train loss: 170.4414, Valid loss: 177.0455
# Epoch 29, Train loss: 169.4117, Valid loss: 176.6555
# Epoch 30, Train loss: 168.5385, Valid loss: 173.9249
# Epoch 31, Train loss: 167.5534, Valid loss: 173.9464
# Epoch 32, Train loss: 167.4428, Valid loss: 178.0386
# Epoch 33, Train loss: 169.5096, Valid loss: 178.1404
# Epoch 34, Train loss: 166.4611, Valid loss: 174.098
# Epoch 35, Train loss: 165.704, Valid loss: 172.1666
# Epoch 36, Train loss: 164.9082, Valid loss: 170.2407
# Epoch 37, Train loss: 163.7289, Valid loss: 170.5482
# Epoch 38, Train loss: 163.4284, Valid loss: 169.6792
# Epoch 39, Train loss: 163.1734, Valid loss: 168.8064
# Epoch 40, Train loss: 162.3129, Valid loss: 168.5404
# Epoch 41, Train loss: 161.3209, Valid loss: 173.0556
# Epoch 42, Train loss: 163.1356, Valid loss: 187.7485
# Epoch 43, Train loss: 166.9918, Valid loss: 168.6818
# Epoch 44, Train loss: 160.1758, Valid loss: 163.9217
# Epoch 45, Train loss: 157.0691, Valid loss: 162.9612
# Epoch 46, Train loss: 157.0803, Valid loss: 168.4462
# Epoch 47, Train loss: 154.2853, Valid loss: 159.1562
# Epoch 48, Train loss: 151.0572, Valid loss: 156.0758
# Epoch 49, Train loss: 148.6532, Valid loss: 155.2964
# ==================================================
# Model result:
# Best epoch is 49, training loss = 148.6532, minimum valid loss = 155.2964
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 50, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.005, 'weight_decay': 0.1}, 'patience': 15}
# Epoch 0, Train loss: 2088.845, Valid loss: 2065.6992
# Epoch 1, Train loss: 1663.2568, Valid loss: 1267.5248
# Epoch 2, Train loss: 829.8659, Valid loss: 769.6889
# Epoch 3, Train loss: 650.9032, Valid loss: 571.0944
# Epoch 4, Train loss: 501.5727, Valid loss: 446.0314
# Epoch 5, Train loss: 410.9057, Valid loss: 371.2562
# Epoch 6, Train loss: 335.6602, Valid loss: 310.9312
# Epoch 7, Train loss: 283.8321, Valid loss: 274.0123
# Epoch 8, Train loss: 244.3107, Valid loss: 237.2325
# Epoch 9, Train loss: 218.7396, Valid loss: 215.9368
# Epoch 10, Train loss: 201.3902, Valid loss: 204.0045
# Epoch 11, Train loss: 190.1785, Valid loss: 191.8229
# Epoch 12, Train loss: 182.308, Valid loss: 185.5459
# Epoch 13, Train loss: 177.3223, Valid loss: 182.177
# Epoch 14, Train loss: 174.0377, Valid loss: 179.2523
# Epoch 15, Train loss: 172.127, Valid loss: 177.6547
# Epoch 16, Train loss: 169.987, Valid loss: 177.7098
# Epoch 17, Train loss: 168.1034, Valid loss: 175.9161
# Epoch 18, Train loss: 166.5278, Valid loss: 174.2004
# Epoch 19, Train loss: 167.2408, Valid loss: 175.9561
# Epoch 20, Train loss: 167.183, Valid loss: 173.1942
# Epoch 21, Train loss: 166.05, Valid loss: 174.7358
# Epoch 22, Train loss: 165.0045, Valid loss: 172.9631
# Epoch 23, Train loss: 165.0487, Valid loss: 179.5047
# Epoch 24, Train loss: 165.4413, Valid loss: 172.3469
# Epoch 25, Train loss: 161.8227, Valid loss: 168.8169
# Epoch 26, Train loss: 161.4546, Valid loss: 168.4084
# Epoch 27, Train loss: 161.4828, Valid loss: 168.398
# Epoch 28, Train loss: 160.4992, Valid loss: 168.9509
# Epoch 29, Train loss: 160.8854, Valid loss: 168.2025
# Epoch 30, Train loss: 160.9226, Valid loss: 172.908
# Epoch 31, Train loss: 162.0022, Valid loss: 170.6177
# Epoch 32, Train loss: 160.548, Valid loss: 166.9918
# Epoch 33, Train loss: 159.3143, Valid loss: 164.5403
# Epoch 34, Train loss: 158.4566, Valid loss: 162.5579
# Epoch 35, Train loss: 157.3464, Valid loss: 162.1565
# Epoch 36, Train loss: 155.4305, Valid loss: 160.7972
# Epoch 37, Train loss: 154.3993, Valid loss: 157.7211
# Epoch 38, Train loss: 151.7488, Valid loss: 155.9586
# Epoch 39, Train loss: 150.3929, Valid loss: 154.1849
# Epoch 40, Train loss: 148.8487, Valid loss: 152.5758
# Epoch 41, Train loss: 147.0319, Valid loss: 151.2127
# Epoch 42, Train loss: 146.0184, Valid loss: 150.858
# Epoch 43, Train loss: 144.8979, Valid loss: 154.3108
# Epoch 44, Train loss: 145.9388, Valid loss: 150.707
# Epoch 45, Train loss: 143.8409, Valid loss: 148.4002
# Epoch 46, Train loss: 140.7913, Valid loss: 148.6401
# Epoch 47, Train loss: 140.2018, Valid loss: 146.1742
# Epoch 48, Train loss: 139.1396, Valid loss: 145.8182
# Epoch 49, Train loss: 138.3526, Valid loss: 144.5714
# ==================================================
# Model result:
# Best epoch is 49, training loss = 138.3526, minimum valid loss = 144.5714
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 50, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.005, 'weight_decay': 1}, 'patience': 15}
# Epoch 0, Train loss: 1798.7556, Valid loss: 1420.3096
# Epoch 1, Train loss: 961.1334, Valid loss: 838.0618
# Epoch 2, Train loss: 690.3725, Valid loss: 600.0017
# Epoch 3, Train loss: 500.4011, Valid loss: 438.1364
# Epoch 4, Train loss: 384.001, Valid loss: 340.9487
# Epoch 5, Train loss: 310.4556, Valid loss: 288.354
# Epoch 6, Train loss: 261.1751, Valid loss: 254.2002
# Epoch 7, Train loss: 228.3751, Valid loss: 223.4675
# Epoch 8, Train loss: 208.4428, Valid loss: 206.5677
# Epoch 9, Train loss: 192.6562, Valid loss: 197.5849
# Epoch 10, Train loss: 182.6513, Valid loss: 189.9466
# Epoch 11, Train loss: 178.0642, Valid loss: 184.8797
# Epoch 12, Train loss: 174.4313, Valid loss: 183.11
# Epoch 13, Train loss: 171.6791, Valid loss: 179.2911
# Epoch 14, Train loss: 169.3924, Valid loss: 179.0652
# Epoch 15, Train loss: 167.904, Valid loss: 175.4134
# Epoch 16, Train loss: 166.0247, Valid loss: 172.0696
# Epoch 17, Train loss: 163.96, Valid loss: 170.3339
# Epoch 18, Train loss: 162.3941, Valid loss: 169.2808
# Epoch 19, Train loss: 160.8377, Valid loss: 167.4714
# Epoch 20, Train loss: 158.2489, Valid loss: 160.693
# Epoch 21, Train loss: 155.1152, Valid loss: 160.5718
# Epoch 22, Train loss: 152.3414, Valid loss: 155.9653
# Epoch 23, Train loss: 150.067, Valid loss: 155.2695
# Epoch 24, Train loss: 145.9968, Valid loss: 153.3474
# Epoch 25, Train loss: 145.0284, Valid loss: 156.0176
# Epoch 26, Train loss: 144.4172, Valid loss: 151.4079
# Epoch 27, Train loss: 141.5512, Valid loss: 155.1017
# Epoch 28, Train loss: 143.2241, Valid loss: 152.0823
# Epoch 29, Train loss: 140.1696, Valid loss: 146.5475
# Epoch 30, Train loss: 137.074, Valid loss: 147.0092
# Epoch 31, Train loss: 135.9857, Valid loss: 143.8284
# Epoch 32, Train loss: 135.4124, Valid loss: 144.161
# Epoch 33, Train loss: 135.3783, Valid loss: 143.0013
# Epoch 34, Train loss: 134.3524, Valid loss: 142.5205
# Epoch 35, Train loss: 133.1186, Valid loss: 143.2772
# Epoch 36, Train loss: 133.9789, Valid loss: 144.7853
# Epoch 37, Train loss: 135.8771, Valid loss: 144.4451
# Epoch 38, Train loss: 134.439, Valid loss: 141.4428
# Epoch 39, Train loss: 132.4143, Valid loss: 142.1951
# Epoch 40, Train loss: 133.1663, Valid loss: 142.0265
# Epoch 41, Train loss: 133.4406, Valid loss: 138.4767
# Epoch 42, Train loss: 132.3584, Valid loss: 140.1341
# Epoch 43, Train loss: 129.9818, Valid loss: 138.3876
# Epoch 44, Train loss: 131.1245, Valid loss: 141.1311
# Epoch 45, Train loss: 131.1234, Valid loss: 140.6773
# Epoch 46, Train loss: 131.3659, Valid loss: 138.2679
# Epoch 47, Train loss: 130.9859, Valid loss: 139.6588
# Epoch 48, Train loss: 130.998, Valid loss: 138.533
# Epoch 49, Train loss: 128.948, Valid loss: 137.6872
# ==================================================
# Model result:
# Best epoch is 49, training loss = 128.948, minimum valid loss = 137.6872
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 50, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.005, 'weight_decay': 5}, 'patience': 15}
# Epoch 0, Train loss: 2002.8012, Valid loss: 1866.7197
# Epoch 1, Train loss: 1408.2089, Valid loss: 977.6875
# Epoch 2, Train loss: 735.8266, Valid loss: 704.7317
# Epoch 3, Train loss: 593.3418, Valid loss: 526.3052
# Epoch 4, Train loss: 472.0369, Valid loss: 422.7941
# Epoch 5, Train loss: 391.6762, Valid loss: 360.3526
# Epoch 6, Train loss: 327.4204, Valid loss: 303.4888
# Epoch 7, Train loss: 272.4462, Valid loss: 256.4993
# Epoch 8, Train loss: 231.6812, Valid loss: 221.9318
# Epoch 9, Train loss: 209.3991, Valid loss: 203.7961
# Epoch 10, Train loss: 194.1254, Valid loss: 193.3798
# Epoch 11, Train loss: 185.0088, Valid loss: 187.1672
# Epoch 12, Train loss: 181.0131, Valid loss: 187.4306
# Epoch 13, Train loss: 178.7656, Valid loss: 182.2137
# Epoch 14, Train loss: 176.0386, Valid loss: 182.2131
# Epoch 15, Train loss: 175.737, Valid loss: 182.4667
# Epoch 16, Train loss: 175.9306, Valid loss: 180.6857
# Epoch 17, Train loss: 175.586, Valid loss: 181.3521
# Epoch 18, Train loss: 174.4907, Valid loss: 185.3883
# Epoch 19, Train loss: 176.6033, Valid loss: 180.0668
# Epoch 20, Train loss: 173.4439, Valid loss: 184.0451
# Epoch 21, Train loss: 172.8653, Valid loss: 181.797
# Epoch 22, Train loss: 172.4868, Valid loss: 178.602
# Epoch 23, Train loss: 171.7706, Valid loss: 191.1208
# Epoch 24, Train loss: 174.7332, Valid loss: 178.2578
# Epoch 25, Train loss: 171.3832, Valid loss: 179.9321
# Epoch 26, Train loss: 173.0259, Valid loss: 183.4099
# Epoch 27, Train loss: 173.0999, Valid loss: 178.5367
# Epoch 28, Train loss: 173.2071, Valid loss: 180.8873
# Epoch 29, Train loss: 172.1071, Valid loss: 178.7132
# Epoch 30, Train loss: 171.6941, Valid loss: 178.4515
# Epoch 31, Train loss: 171.2509, Valid loss: 176.7737
# Epoch 32, Train loss: 173.1942, Valid loss: 182.7718
# Epoch 33, Train loss: 171.5927, Valid loss: 179.113
# Epoch 34, Train loss: 174.5533, Valid loss: 183.0409
# Epoch 35, Train loss: 173.2962, Valid loss: 180.3463
# Epoch 36, Train loss: 170.7098, Valid loss: 176.0492
# Epoch 37, Train loss: 168.6255, Valid loss: 178.4423
# Epoch 38, Train loss: 168.4831, Valid loss: 176.3661
# Epoch 39, Train loss: 170.1595, Valid loss: 175.2931
# Epoch 40, Train loss: 170.3144, Valid loss: 178.2477
# Epoch 41, Train loss: 167.0286, Valid loss: 174.4277
# Epoch 42, Train loss: 168.1298, Valid loss: 171.9496
# Epoch 43, Train loss: 167.8711, Valid loss: 172.5504
# Epoch 44, Train loss: 167.2701, Valid loss: 181.0676
# Epoch 45, Train loss: 168.6882, Valid loss: 180.761
# Epoch 46, Train loss: 168.4589, Valid loss: 171.1065
# Epoch 47, Train loss: 167.1045, Valid loss: 179.4342
# Epoch 48, Train loss: 165.6317, Valid loss: 175.1111
# Epoch 49, Train loss: 164.3399, Valid loss: 170.7175
# ==================================================
# Model result:
# Best epoch is 49, training loss = 164.3399, minimum valid loss = 170.7175
# ==================================================
# Parameter settings:
# {'num_batch': 512, 'num_epoch': 50, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.005, 'weight_decay': 10}, 'patience': 15}
# Epoch 0, Train loss: 2155.2813, Valid loss: 2268.0282
# Epoch 1, Train loss: 2100.8279, Valid loss: 2144.0159
# Epoch 2, Train loss: 1800.6754, Valid loss: 1479.5783
# Epoch 3, Train loss: 1011.6385, Valid loss: 818.6609
# Epoch 4, Train loss: 685.2074, Valid loss: 600.9169
# Epoch 5, Train loss: 539.9602, Valid loss: 480.566
# Epoch 6, Train loss: 431.7569, Valid loss: 386.7208
# Epoch 7, Train loss: 345.0646, Valid loss: 305.9365
# Epoch 8, Train loss: 263.3208, Valid loss: 242.9334
# Epoch 9, Train loss: 214.7983, Valid loss: 209.8628
# Epoch 10, Train loss: 194.4438, Valid loss: 200.9502
# Epoch 11, Train loss: 187.5148, Valid loss: 199.7311
# Epoch 12, Train loss: 184.5918, Valid loss: 189.4713
# Epoch 13, Train loss: 179.9918, Valid loss: 187.4394
# Epoch 14, Train loss: 178.5655, Valid loss: 192.0675
# Epoch 15, Train loss: 178.5791, Valid loss: 182.4849
# Epoch 16, Train loss: 176.789, Valid loss: 185.4051
# Epoch 17, Train loss: 176.2872, Valid loss: 187.9364
# Epoch 18, Train loss: 178.4294, Valid loss: 183.649
# Epoch 19, Train loss: 176.8456, Valid loss: 182.9807
# Epoch 20, Train loss: 178.558, Valid loss: 182.8618
# Epoch 21, Train loss: 177.1398, Valid loss: 181.6897
# Epoch 22, Train loss: 177.5593, Valid loss: 182.5111
# Epoch 23, Train loss: 174.8764, Valid loss: 181.8811
# Epoch 24, Train loss: 175.7626, Valid loss: 181.6043
# Epoch 25, Train loss: 177.1243, Valid loss: 188.1027
# Epoch 26, Train loss: 180.0677, Valid loss: 187.1596
# Epoch 27, Train loss: 175.8502, Valid loss: 181.642
# Epoch 28, Train loss: 174.627, Valid loss: 180.7223
# Epoch 29, Train loss: 175.1578, Valid loss: 182.1882
# Epoch 30, Train loss: 176.5035, Valid loss: 181.9569
# Epoch 31, Train loss: 174.2783, Valid loss: 181.4486
# Epoch 32, Train loss: 175.2992, Valid loss: 180.7959
# Epoch 33, Train loss: 176.3716, Valid loss: 184.4767
# Epoch 34, Train loss: 175.0132, Valid loss: 185.0285
# Epoch 35, Train loss: 175.1406, Valid loss: 180.5586
# Epoch 36, Train loss: 176.6204, Valid loss: 184.8456
# Epoch 37, Train loss: 175.2895, Valid loss: 184.3284
# Epoch 38, Train loss: 175.8302, Valid loss: 181.0198
# Epoch 39, Train loss: 176.2198, Valid loss: 182.3513
# Epoch 40, Train loss: 178.9649, Valid loss: 193.8512
# Epoch 41, Train loss: 180.9144, Valid loss: 185.0431
# Epoch 42, Train loss: 177.6591, Valid loss: 187.942
# Epoch 43, Train loss: 175.8843, Valid loss: 185.9321
# Epoch 44, Train loss: 174.834, Valid loss: 181.4532
# Epoch 45, Train loss: 174.434, Valid loss: 183.6441
# Epoch 46, Train loss: 175.8552, Valid loss: 180.8781
# Epoch 47, Train loss: 174.4113, Valid loss: 180.9742
# Epoch 48, Train loss: 175.3663, Valid loss: 181.988
# Epoch 49, Train loss: 174.2234, Valid loss: 182.2675
# ==================================================
# Model result:
# Best epoch is 35, training loss = 175.1406, minimum valid loss = 180.5586
# ==================================================

# %%
model_save_path = "models/HW1.model_pth"
print("="*10, "Tuning Result", "="*10)
print(f"Best params are: {best_params}")
print(f"Training MSE: {best_train_loss}, Valid MSE: {best_valid_loss}")
torch.save(best_model.state_dict(), model_save_path)
# Out:
# ========== Tuning Result ==========
# Best params are: {'num_batch': 512, 'num_epoch': 50, 'optimizer': 'Adam', 'optim_hparams': {'lr': 0.1, 'weight_decay': 0.1}, 'patience': 5}
# Training MSE: 125.47455537094534, Valid MSE: 133.23816867991806

# %%
plot_curve(best_loss_record["train"], best_loss_record["valid"])

# %% [markdown]
# # Testing

# %%
y_pred = test(best_model, test_set, device)

# %%
def save_pred(preds, file):
    ''' Save predictions to specified file '''
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['INDEX', 'PM2.5'])
        for i, p in enumerate(preds):
            writer.writerow([i+1, p])

# %%
submit_path = "./submission/submission_1101_4.csv"
save_pred(y_pred, submit_path)
# Out:
# Saving results to ./submission/submission_1101_4.csv

# %% [markdown]
# # EDA

# %%
for col in data_train.columns:
    plt.plot(data_train[col])
    plt.plot(data_train["PM2.5"])
    plt.legend([col, "PM2.5"])
    plt.title(col)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-088d69fb3456> in <module>()
# ----> 1 for col in data_train.columns:
#       2     plt.plot(data_train[col])
#       3     plt.plot(data_train["PM2.5"])
#       4     plt.legend([col, "PM2.5"])
#       5     plt.title(col)
#
# NameError: name 'data_train' is not defined

# %%
for col in data_train.columns:
    plt.boxplot(data_train[col])
    plt.title(col)
    plt.show()

# %%
data_test
# Out:
#       AMB_TEMP  CH4    CO  NMHC    NO   NO2   NOx   PM10    RH  SO2
# 0         19.0  2.1  0.40  0.19   1.8  20.0  22.0   57.0  91.0  2.1
# 1         18.0  2.2  0.46  0.18   3.9  19.0  23.0   65.0  92.0  2.6
# 2         18.0  2.3  0.46  0.17   5.3  19.0  25.0   61.0  92.0  2.6
# 3         18.0  2.3  0.46  0.19  14.0  22.0  37.0   58.0  93.0  2.5
# 4         18.0  2.2  0.37  0.16   4.1  17.0  21.0   41.0  93.0  2.0
# ...        ...  ...   ...   ...   ...   ...   ...    ...   ...  ...
# 8755      17.0  2.2  0.85  0.17   0.9  16.0  17.0  177.0  69.0  2.7
# 8756      17.0  2.2  0.82  0.17   0.9  18.0  18.0  143.0  70.0  2.3
# 8757      17.0  2.1  0.78  0.16   1.1  15.0  17.0  110.0  72.0  2.3
# 8758      16.0  2.1  0.73  0.14   1.2  17.0  18.0   96.0  73.0  2.4
# 8759      16.0  2.1  0.65  0.13   1.3  17.0  18.0   87.0  73.0  2.3
#
# [8760 rows x 10 columns]

# %% [markdown]
# # Deprecated

# %%
model = NeuralNet(train_set.dataset.dim).to(device)
model_check_point = torch.load(model_save_path, map_location='cpu')
model.load_state_dict(model_check_point)
# Out:
# <All keys matched successfully>
